# %% [markdown]
# # Data Processing Pipeline

# %%
import pandas as pd 
import numpy as np 
import bamboolib as bam 
bam.enable()
DATA_PATH = 'intermediate/Pivoted_Data_10Cities.xlsx'
# Out:
# Success: the bamboolib extension was enabled successfully. You can disable it via 'bam.disable()'. You will now see a magic bamboolib button when you display your dataframes, for example via 'df'

# %% [markdown]
# ## Reading Dataset

# %%
data = pd.read_excel(DATA_PATH)

# %%
data
# Out:
#        Provinsi Kota Bandung Kota Makassar DKI Jakarta  Medan Surabaya  \
# 0    02/01/2020        79200         43550       72900  39550    75800
# 1    03/01/2020        79200         43550       72900  39550    75800
# 2    06/01/2020        79200         43550       72900  39550    75800
# 3    07/01/2020        79200         43550       72900  39550    75800
# 4    08/01/2020        77900         45500       72500  40500    87000
# ..          ...          ...           ...         ...    ...      ...
# 700  14/11/2022        82450         48550       99350  40750    82350
# 701  15/11/2022        82450         48550       99350  40750    82350
# 702  16/11/2022        75450         50050       96350  40750    77600
# 703  17/11/2022        75450         50050       96350  40750    77600
# 704  18/11/2022        75450         50050       96350  40750    77600
#
#     Kota Pekanbaru Kota Batam Kota Palembang Kota Yogyakarta  Kota Balikpapan
# ...

# %%
#rename provinsi into "tanggal"
data = data.rename(columns={'Provinsi':'tanggal'})
data['tanggal'] = pd.to_datetime(data['tanggal'])
# Out:
# 2022-11-19 16:29:06,663 [28180] WARNING  py.warnings:109: [JupyterRequire] C:\Users\Fakhri Robi Aulia\AppData\Local\Temp\ipykernel_28180\3604518599.py:3: UserWarning:
#
# Parsing '13/01/2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
#
# 2022-11-19 16:29:06,664 [28180] WARNING  py.warnings:109: [JupyterRequire] C:\Users\Fakhri Robi Aulia\AppData\Local\Temp\ipykernel_28180\3604518599.py:3: UserWarning:
#
# Parsing '14/01/2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
#
# 2022-11-19 16:29:06,665 [28180] WARNING  py.warnings:109: [JupyterRequire] C:\Users\Fakhri Robi Aulia\AppData\Local\Temp\ipykernel_28180\3604518599.py:3: UserWarning:
#
# Parsing '15/01/2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#
#
# ...

# %%
data.dtypes
#seems like all data types are object.Check Unique Values
# Out:
# tanggal            datetime64[ns]
# Kota Bandung               object
# Kota Makassar              object
# DKI Jakarta                object
# Medan                      object
# Surabaya                   object
# Kota Pekanbaru             object
# Kota Batam                 object
# Kota Palembang             object
# Kota Yogyakarta            object
# Kota Balikpapan             int64
# dtype: object

# %%
data.columns
# Out:
# Index(['tanggal', 'Kota Bandung', 'Kota Makassar', 'DKI Jakarta', 'Medan',
#        'Surabaya', 'Kota Pekanbaru', 'Kota Batam', 'Kota Palembang',
#        'Kota Yogyakarta', 'Kota Balikpapan'],
#       dtype='object')

# %%
data['Kota Bandung'].unique()
# there is '-' in Kota Bandung unique val, replace into np,NaN
# Out:
# array([79200, 77900, 86600, 93500, 90800, 94750, 94100, 87350, 87200,
#        88050, 77800, 74900, 79300, 73900, 71050, 58300, 56900, 55900,
#        42700, 43300, 42550, 43050, 47200, 46100, 45150, 42600, 42950,
#        46950, 45950, 48200, 53300, 56150, 61550, 64250, 60900, 64000,
#        62950, 70250, 74050, 72950, 86700, 85950, 83650, 78200, 82600,
#        83100, 87300, 83850, 83950, 82700, 79600, 79100, 84800, 84700,
#        84450, 75100, 85200, 80000, 72850, 65700, 59200, 55200, 53550,
#        53850, 55350, 50000, 48500, 45500, 43150, 38650, 38900, 43600,
#        47650, 48400, 47450, 51600, 54550, '-', 55750, 54600, 71500, 68900,
#        65300, 62300, 57250, 55500, 54200, 56550, 56500, 63950, 68450,
#        73150, 70900, 70350, 80850, 71150, 73800, 82050, 93800, 98400,
#        107650, 125250, 132800, 131050, 126450, 122000, 116550, 109450,
#        108700, 103750, 103200, 96200, 94700, 95850, 86950, 82450, 75450],
#       dtype=object)

# %%
data = data.replace('-',np.NaN)

# %%
#check dtypes again 

cities = ['Kota Bandung', 'Kota Makassar', 'DKI Jakarta', 'Medan',
       'Surabaya', 'Kota Pekanbaru', 'Kota Batam', 'Kota Palembang',
       'Kota Yogyakarta', 'Kota Balikpapan']
data[cities] = data[cities].astype('float')

# %%
data.dtypes
# Out:
# tanggal            datetime64[ns]
# Kota Bandung              float64
# Kota Makassar             float64
# DKI Jakarta               float64
# Medan                     float64
# Surabaya                  float64
# Kota Pekanbaru            float64
# Kota Batam                float64
# Kota Palembang            float64
# Kota Yogyakarta           float64
# Kota Balikpapan           float64
# dtype: object

# %%
data = data.rename(columns={'Kota Bandung': 'Bandung', 'Kota Makassar': 'Makassar', 'Kota Pekanbaru': 'Pekanbaru', 'Kota Batam': 'Batam', 'Kota Palembang': 'Palembang', 'Kota Yogyakarta': 'Yogyakarta', 'Kota Balikpapan': 'Balikpapan'})
data
# Out:
#        tanggal  Kota Bandung  Kota Makassar  DKI Jakarta    Medan  Surabaya  \
# 0   2020-02-01       79200.0        43550.0      72900.0  39550.0   75800.0
# 1   2020-03-01       79200.0        43550.0      72900.0  39550.0   75800.0
# 2   2020-06-01       79200.0        43550.0      72900.0  39550.0   75800.0
# 3   2020-07-01       79200.0        43550.0      72900.0  39550.0   75800.0
# 4   2020-08-01       77900.0        45500.0      72500.0  40500.0   87000.0
# ..         ...           ...            ...          ...      ...       ...
# 700 2022-11-14       82450.0        48550.0      99350.0  40750.0   82350.0
# 701 2022-11-15       82450.0        48550.0      99350.0  40750.0   82350.0
# 702 2022-11-16       75450.0        50050.0      96350.0  40750.0   77600.0
# 703 2022-11-17       75450.0        50050.0      96350.0  40750.0   77600.0
# 704 2022-11-18       75450.0        50050.0      96350.0  40750.0   77600.0
#
# ...

# %%
# Data From Hargapangan.id is only mantained on non holiday calendar dates so we need to add missing dates
